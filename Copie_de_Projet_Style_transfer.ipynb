# %% [markdown]
# <a href="https://colab.research.google.com/github/Nawel-Bellil/AI---Deep-Learning--/blob/main/Copie_de_Projet_Style_transfer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To implement a neural style transfer algorithm that takes two images—a content image and a style image—and blends them to produce a new image that retains the content of the first image but is stylized like the second.
# Tools and Libraries:
#
#    Python
#
#   TensorFlow/Keras or PyTorch
#
#   OpenCV or PIL (for image processing)
#
#   NumPy
#
#   Matplotlib (for visualization)

# %%
pip install tensorflow numpy matplotlib opencv-python

# %%
##Importez un modéle keras avec tensorflow keras
import tensorflow.keras
#...Continuez ici :

# %%
#Charger les images et Normalisez-les!

import cv2
import numpy as np

def load_image(image_path):
    pass
    #Implémentez cette fonction


content_image = load_image('content.jpg') #Vos images
style_image = load_image('style.jpg') #Vos images

# %%
#Fonctions de loss, à vous de choisir celle qui convient le mieux
import tensorflow as tf
def content_loss(content, generated):
    return tf.reduce_mean(tf.square(content - generated))

def gram_matrix(input_tensor):
    result = tf.linalg.einsum('bijc,bijd->bcd', input_tensor, input_tensor)
    input_shape = tf.shape(input_tensor)
    num_locations = tf.cast(input_shape[1]*input_shape[2], tf.float32)
    return result / num_locations

def style_loss(style, generated):
    style_gram = gram_matrix(style)
    generated_gram = gram_matrix(generated)
    return tf.reduce_mean(tf.square(style_gram - generated_gram))

def total_variation_loss(image):
    x_deltas = image[:, :-1, :-1, :] - image[:, 1:, :-1, :]
    y_deltas = image[:, :-1, :-1, :] - image[:, :-1, 1:, :]
    return tf.reduce_mean(tf.square(x_deltas)) + tf.reduce_mean(tf.square(y_deltas))

# %%
#Optimisation : choisissez un algorithme d'optimisation pour ce projet
import tensorflow as tf

optimizer = tf.optimizers.Adam(learning_rate=0.02)

def train_step(generated_image):
    #Implémentez cette fonction ici
    pass

# %%
import tensorflow as tf

generated_image = tf.Variable(content_image)

epochs = 1000
for i in range(epochs):
    train_step(generated_image)
    if i % 100 == 0:
        print(f"Epoch {i}, Loss: {total_loss.numpy()}")

# %%
#Partie post processing pour sauvegarder l'image
def save_image(image, filename):
    pass
    #Implémentez cette fonction

save_image(generated_image, 'styled_image.jpg')

# %%
#Partie visualisation :
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))

plt.subplot(1, 3, 1)
plt.title('Content Image')
plt.imshow(cv2.cvtColor(cv2.imread('content.jpg'), cv2.COLOR_BGR2RGB))

plt.subplot(1, 3, 2)
plt.title('Style Image')
plt.imshow(cv2.cvtColor(cv2.imread('style.jpg'), cv2.COLOR_BGR2RGB))

plt.subplot(1, 3, 3)
plt.title('Styled Image')
plt.imshow(cv2.cvtColor(cv2.imread('styled_image.jpg'), cv2.COLOR_BGR2RGB))

plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
https://drive.google.com/file/u/3/d/1GBiMgzV1ArqTiNgYEhnnZIs2QdeiMWIx/edit?pli=1
